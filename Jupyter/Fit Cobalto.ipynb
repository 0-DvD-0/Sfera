# %%
import matplotlib.pyplot as plt
import numpy as np

from lmfit.models import GaussianModel, ExponentialModel, \
                         ThermalDistributionModel, StepModel #Modelli vari, l'ultimo è Fermi (o Bose)

# %% [markdown]
# READ ME:
# 1) Inserire il proprio path dei dati da analizzare in una variabile apposita
# 2) Inserire tutti gli aggiustamenti che servono per fare il fit di un dato canale all'interno di un if

# %%
def load_histo(dat_PATH):
    data = np.loadtxt(dat_PATH, skiprows=0, comments='==')
    noises_edges = np.zeros((int(data.shape[0]/2), data.shape[1]))       #np.array([[]] * int(data.shape[0]/2))
    noises_values = np.zeros((int(data.shape[0]/2), data.shape[1]))       #np.array([[]] * int(data.shape[0]/2))

    for i in range(int(data.shape[0]/2)):
        noises_edges[i] = (data[2 * i])
        noises_values[i] = (data[2 * i + 1])

    return noises_edges, noises_values


def rebin(data, factor):
    if len(data) % factor != 0:
        raise ValueError("Length of data must be divisible by factor.")
    rebinned_data = np.sum(data.reshape(-1, factor), axis=1)
    return rebinned_data

# %%
PATH_SAM="../Dati/23-04/Run_chall_Co_HHHHR_1000bin_ChargeHistos_4_23_2024.dat"
edge_N, bin_N = load_histo(PATH_SAM)

channel = 14

if(channel == 12 or channel == 13 or channel == 1):
    exit()

channel_idx = [0, -1, 1, 2, 3, 4, 5, 6, 7, -1, 8, 9, -1, -1, 10, 11]

    
edge_N = edge_N[channel_idx[channel]]
bin_N = bin_N[channel_idx[channel]]

rebin_fact = 1
bin_N = rebin(bin_N, rebin_fact)
tmp = []
for i in range(len(edge_N)):
    if(i % rebin_fact == 0):
        tmp.append(edge_N[i])

tmp.append(edge_N[-1])
edge_N = np.array(tmp)

centers_N = np.convolve(edge_N, [0.5, 0.5], "valid")
err_N = np.sqrt(bin_N)

# %%
lim_list = [[-1000, -190],  #ch0
            [-1, -1],      #ch1
            [-1000, -175],  #ch2
            [-1000, -145],  #ch3
            [-4000, -165],  #ch4
            [-1000, -175],  #ch5
            [-1000, -155],  #ch6
            [-4000, -1000],  #ch7
            [-4000, -170],  #ch8
            [-1000, -160],  #ch9
            [-1000, -120],  #ch10
            [-1000, -165],  #ch11
            [-1, -1],      #ch12
            [-1, -1],      #ch13
            [-1800, -300],  #ch14
            [-1000, -160]   #ch15
            ]


lim_N = lim_list[channel]
#plt.text(centers_N.min() * 0.85, bin_N.max() * 95 / 100, f'{bin_N.sum() = }', fontsize=10, color='black', ha='center',
 #        bbox=dict(facecolor='white', alpha=0.5, edgecolor='blue', boxstyle='round,pad=0.5'))
plt.bar(centers_N, bin_N, width = 4)
plt.xlim(lim_N)
plt.grid()
plt.xlabel("Charge [pC]")
plt.ylabel("counts")

plt.ylim([0, 8000])
# Out:
# (0.0, 8000.0)

# %%
err_N = err_N[np.where((centers_N > lim_N[0]) & (centers_N < lim_N[1]))]
bin_N = bin_N[np.where((centers_N > lim_N[0]) & (centers_N < lim_N[1]))]
centers_N = centers_N[np.where((centers_N > lim_N[0]) & (centers_N < lim_N[1]))]

# %%
np.where(err_N == 0)
# Out:
# (array([], dtype=int64),)

# %%
#DEFINIAMO IL MODELLO
exp1   = ExponentialModel(prefix='e1_') #Esponenziale 
gauss1 = GaussianModel(prefix='g1_')    #Gaussiana
gauss2 = GaussianModel(prefix='g2_')    #Gaussiana
sigmoid1 = StepModel(form = "logistic", prefix = "s1_") #Sigmoide
sigmoid2 = StepModel(form = "logistic", prefix = "s2_") #Sigmoide
sigmoid3 = StepModel(form = "logistic", prefix = "s3_") #Sigmoide



params = exp1.guess(bin_N, x=centers_N)           #Inizializzo i parametri dell'esponenziale
params.update(sigmoid1.guess(bin_N, x=centers_N))
params.update(gauss1.make_params(amplitude = 30000, center = -1100, sigma = 90))   
params.update(gauss2.make_params(amplitude = 15500, center = -900, sigma = 60)) 
params["g1_amplitude"].min = 0
params["g2_amplitude"].min = 0  

params["g1_center"].max = -800
params["g2_center"].max = -800  

params["e1_decay"].value = -140
params["e1_amplitude"].value = 914


params.update(sigmoid2.make_params(amplitude = 1000, center = -100, sigma = 60))
params.update(sigmoid3.make_params(amplitude = 1000, center = -1250, sigma = 60))

params["s1_amplitude"].min = 0  
params["s2_amplitude"].min = 0  
params["s3_amplitude"].min = 0  

params["s1_amplitude"].value = 9
params["s1_sigma"].value = 500
#params["s3_amplitude"].value = 50  

#params["s2_amplitude"].max = 120
#params["s3_amplitude"].max = 150

params["s1_center"].value = -1000  
#params["s2_center"].value = -450  
#params["s3_center"].value = -440  

params["s2_center"].min = -1300  
params["s3_center"].min = -1300 

#params["s2_sigma"].value = 20
#params["s3_sigma"].value = 20  






model = exp1 + gauss1 + gauss2 + sigmoid1 + sigmoid2 + sigmoid3

# %%
#FIT

result = model.fit(bin_N, params, x = centers_N, weights = 1 / err_N)


fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

#_ = ax1.hist(bin_N, range = lim_N, color = "cyan", alpha = 0.5, label = "Dati sperimentali")
ax1.set_xlabel('Charge [pC]')
ax1.set_ylabel('Counts')
ax1.legend()

comps = result.eval_components()                        #Plotto il best fit + le componenti
ax1.plot(centers_N, result.best_fit, label='best fit', zorder = 10)
ax1.plot(centers_N, comps['g1_'], label='Fotoelettrico 1', ls = "--")
ax1.plot(centers_N, comps['s2_'], label='Compton 1', ls = "--")
ax1.plot(centers_N, comps['g2_'], label='Fotoelettrico 2', ls = "--")
ax1.plot(centers_N, comps['s3_'], label='Compton 2', ls = "--")

ax1.plot(centers_N, comps['e1_'] + comps['s1_'], label='Background')
ax1.plot(centers_N, comps['e1_'], label='Background Exp', ls = "-.")
ax1.plot(centers_N, comps['s1_'], label='Background FD', ls = "-.")

ax1.legend()
ax1.errorbar(centers_N, bin_N, err_N, color = "red", fmt='|')
ax1.grid()

residueCs = bin_N - result.best_fit
norm_resCs = residueCs / err_N

ax2.errorbar(centers_N, norm_resCs, 1, ls = "", marker = ".")
ax2.grid()

ax2.set_xlabel('Charge [pC]')
ax2.set_ylabel('Normalized residues')

xlim = ax2.get_xlim()

ax2.fill_between(xlim, [-1, -1], [1, 1], color = "orange", alpha = 0.2, label = r'$1\sigma$')
ax2.fill_between(xlim, [-2, -2], [-1, -1], color = "lightgreen", alpha = 0.2, label = r'$2\sigma$')
ax2.fill_between(xlim, [1, 1], [2, 2], color = "lightgreen", alpha = 0.2)
ax2.fill_between(xlim, [2, 2], [3, 3], color = "lightgray", alpha = 0.2, label = r'$3\sigma$')
ax2.fill_between(xlim, [-3, -3], [-2, -2], color = "lightgray", alpha = 0.2)

ax2.legend()
fig.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(result.fit_report())
# Out:
# [[Model]]
#     (((((Model(exponential, prefix='e1_') + Model(gaussian, prefix='g1_')) + Model(gaussian, prefix='g2_')) + Model(step, prefix='s1_', form='logistic')) + Model(step, prefix='s2_', form='logistic')) + Model(step, prefix='s3_', form='logistic'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1554
#     # data points      = 305
#     # variables        = 17
#     chi-square         = 523.685853
#     reduced chi-square = 1.81835366
#     Akaike info crit   = 198.876964
#     Bayesian info crit = 262.122264
#     R-squared          = 0.99999941
# [[Variables]]
#     e1_amplitude:  42853.1648 +/- 4931.63984 (11.51%) (init = 914)
#     e1_decay:     -117.743876 +/- 5.52044756 (4.69%) (init = -140)
#     s1_amplitude:  132.770242 +/- 80.0433514 (60.29%) (init = 9)
#     s1_center:    -1597.39398 +/- 333.294035 (20.86%) (init = -1000)
#     s1_sigma:      268.562645 +/- 153.120762 (57.01%) (init = 500)
#     g1_amplitude:  203783.827 +/- 4154.15257 (2.04%) (init = 30000)
#     g1_center:    -1042.00818 +/- 0.57649956 (0.06%) (init = -1100)
#     g1_sigma:      37.4350636 +/- 0.57968733 (1.55%) (init = 90)
#     g1_fwhm:       88.1528365 +/- 1.36505932 (1.55%) == '2.3548200*g1_sigma'
#     g1_height:     2171.70697 +/- 28.4498797 (1.31%) == '0.3989423*g1_amplitude/max(1e-15, g1_sigma)'
#     g2_amplitude:  241959.102 +/- 12152.0672 (5.02%) (init = 15500)
#     g2_center:    -919.753226 +/- 0.61566751 (0.07%) (init = -900)
#     g2_sigma:      39.5501290 +/- 0.99475242 (2.52%) (init = 60)
#     g2_fwhm:       93.1334347 +/- 2.34246287 (2.52%) == '2.3548200*g2_sigma'
#     g2_height:     2440.64237 +/- 74.3785615 (3.05%) == '0.3989423*g2_amplitude/max(1e-15, g2_sigma)'
#     s2_amplitude:  54.6247305 +/- 48.3094547 (88.44%) (init = 1000)
#     s2_center:    -1245.71098 +/- 38.5106072 (3.09%) (init = -100)
#     s2_sigma:      43.9778345 +/- 36.4879312 (82.97%) (init = 60)
#     s3_amplitude:  2841.72937 +/- 68.5179833 (2.41%) (init = 1000)
#     s3_center:    -840.109861 +/- 3.68558912 (0.44%) (init = -1250)
#     s3_sigma:      57.8275670 +/- 5.04633497 (8.73%) (init = 60)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(s1_amplitude, s1_center)    = +0.9994
#     C(e1_amplitude, e1_decay)     = +0.9920
#     C(s1_center, s1_sigma)        = +0.9851
#     C(s1_amplitude, s1_sigma)     = +0.9834
#     C(s2_amplitude, s2_sigma)     = +0.9388
#     C(g2_amplitude, s3_sigma)     = -0.9216
#     C(s1_amplitude, s2_amplitude) = -0.8933
#     C(s1_center, s2_amplitude)    = -0.8872
#     C(g2_amplitude, g2_sigma)     = +0.8812
#     C(s1_sigma, s2_amplitude)     = -0.8385
#     C(g2_amplitude, s3_center)    = +0.8332
#     C(s3_amplitude, s3_sigma)     = +0.8036
#     C(e1_decay, s3_amplitude)     = +0.7947
#     C(s1_amplitude, s2_sigma)     = -0.7850
#     C(g2_sigma, s3_center)        = +0.7833
#     C(s1_center, s2_sigma)        = -0.7750
#     C(g1_amplitude, g1_sigma)     = +0.7662
#     C(e1_amplitude, s3_amplitude) = +0.7603
#     C(g2_sigma, s3_sigma)         = -0.7226
#     C(s1_sigma, s2_sigma)         = -0.7074
#     C(s3_center, s3_sigma)        = -0.6885
#     C(e1_decay, s3_sigma)         = +0.6787
#     C(s2_center, s2_sigma)        = +0.6501
#     C(g2_amplitude, s3_amplitude) = -0.6332
#     C(e1_amplitude, s3_sigma)     = +0.6272
#     C(s2_amplitude, s2_center)    = +0.6056
#     C(g1_center, g1_sigma)        = +0.5556
#     C(g1_sigma, s2_center)        = -0.5467
#     C(g1_amplitude, s2_center)    = -0.5306
#     C(e1_decay, g2_amplitude)     = -0.5289
#     C(g1_amplitude, g2_center)    = +0.5039
#     C(e1_amplitude, g2_amplitude) = -0.4834
#     C(g2_sigma, s3_amplitude)     = -0.4813
#     C(g1_center, g2_center)       = +0.4630
#     C(g2_center, s3_center)       = +0.4474
#     C(g1_center, g2_sigma)        = -0.4470
#     C(g1_amplitude, g1_center)    = +0.4329
#     C(g1_sigma, g2_center)        = +0.4231
#     C(g1_amplitude, s2_sigma)     = -0.4181
#     C(g2_center, s3_sigma)        = -0.4030
#     C(g1_sigma, s2_amplitude)     = -0.3932
#     C(g1_sigma, s2_sigma)         = -0.3916
#     C(g1_amplitude, s3_sigma)     = -0.3754
#     C(e1_decay, g2_sigma)         = -0.3749
#     C(g2_amplitude, g2_center)    = +0.3713
#     C(s2_center, s3_center)       = +0.3656
#     C(s3_amplitude, s3_center)    = -0.3541
#     C(g1_amplitude, s2_amplitude) = -0.3516
#     C(s2_center, s3_amplitude)    = -0.3475
#     C(e1_amplitude, g2_sigma)     = -0.3408
#     C(g1_sigma, g2_sigma)         = -0.3404
#     C(s1_sigma, s3_amplitude)     = -0.3345
#     C(s1_center, s3_amplitude)    = -0.3141
#     C(s1_amplitude, s3_amplitude) = -0.3095
#     C(g2_sigma, s2_center)        = +0.2761
#     C(s2_center, s3_sigma)        = -0.2678
#     C(e1_decay, g1_amplitude)     = -0.2657
#     C(g1_amplitude, g2_amplitude) = +0.2553
#     C(e1_amplitude, g1_amplitude) = -0.2473
#     C(s1_amplitude, s2_center)    = -0.2406
#     C(g2_center, s3_amplitude)    = -0.2376
#     C(s2_amplitude, s3_center)    = +0.2356
#     C(s1_center, s2_center)       = -0.2341
#     C(g2_amplitude, s2_center)    = +0.2305
#     C(g2_sigma, s2_amplitude)     = +0.2305
#     C(g1_center, g2_amplitude)    = -0.2120
#     C(g2_amplitude, s2_amplitude) = +0.2098
#     C(s1_sigma, s2_center)        = -0.2020
#     C(g1_sigma, s3_center)        = -0.1947
#     C(e1_decay, s2_amplitude)     = -0.1903
#     C(g1_amplitude, s3_amplitude) = -0.1900
#     C(s2_amplitude, s3_sigma)     = -0.1861
#     C(g2_center, g2_sigma)        = +0.1837
#     C(e1_decay, g2_center)        = -0.1815
#     C(s1_amplitude, g1_sigma)     = +0.1783
#     C(s2_sigma, s3_center)        = +0.1763
#     C(s1_center, g1_sigma)        = +0.1735
#     C(e1_decay, s2_center)        = -0.1696
#     C(s1_amplitude, g1_amplitude) = +0.1685
#     C(e1_amplitude, g2_center)    = -0.1649
#     C(s1_center, g1_amplitude)    = +0.1627
#     C(e1_amplitude, s2_amplitude) = -0.1621
#     C(g1_center, s3_center)       = -0.1551
#     C(e1_decay, s3_center)        = -0.1541
#     C(e1_amplitude, s2_center)    = -0.1520
#     C(s1_sigma, g1_sigma)         = +0.1457
#     C(g2_sigma, s2_sigma)         = +0.1417
#     C(s1_sigma, g1_amplitude)     = +0.1287
#     C(e1_amplitude, s3_center)    = -0.1278
#     C(g1_sigma, g2_amplitude)     = -0.1268
#     C(e1_decay, s2_sigma)         = -0.1192

# %%
range_1 = [60, 133]
gauss1 = GaussianModel(prefix='g1_')    #Gaussiana
model2 = gauss1
params.update(gauss1.guess(bin_N[range_1[0]:range_1[1]], x = centers_N[range_1[0]:range_1[1]]))
result2 = model2.fit(bin_N[range_1[0]:range_1[1]], 
                     params, x = centers_N[range_1[0]:range_1[1]], 
                     weights = 1 / err_N[range_1[0]:range_1[1]])


_ = plt.plot(centers_N[range_1[0]:range_1[1]], result2.best_fit, label='best fit', zorder = 10)
_ = plt.errorbar(centers_N[range_1[0]:range_1[1]], 
             bin_N[range_1[0]:range_1[1]], 
             err_N[range_1[0]:range_1[1]], color = "red", fmt='|')

print(f'Picco 1 a {result2.params["g1_center"].value: .2f} pC')
# Out:
# Picco 1 a  0.00 pC

# %%
range_2 = [123, 200]
gauss2 = GaussianModel(prefix='g1_')    #Gaussiana
model3 = gauss2
result3 = model3.fit(bin_N[range_2[0]:range_2[1]], 
                     params, x = centers_N[range_2[0]:range_2[1]], 
                     weights = 1 / err_N[range_2[0]:range_2[1]])


_ = plt.plot(centers_N[range_2[0]:range_2[1]], result3.best_fit, label='best fit', zorder = 10)
_ = plt.errorbar(centers_N[range_2[0]:range_2[1]], 
             bin_N[range_2[0]:range_2[1]], 
             err_N[range_2[0]:range_2[1]], color = "red", fmt='|')

print(f'Picco 2 a {result3.params["g1_center"].value: .2f} pC')
# Out:
# Picco 2 a -923.80 pC
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.
